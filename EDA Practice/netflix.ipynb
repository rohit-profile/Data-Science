# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("netflix_titles.csv")

# %%
df.head ()

# %%
df.info()

# %% [markdown]
# #Kaunsa content zyada hai (Movies ya TV Shows)
#
# #Kis year me zyada content add hua
#
# #Popular genres
#
# #Rating distribution

# %%
df.columns.value_counts().sort_index()

# %%
df.type.value_counts()

# %% [markdown]
# ### Observation
# Most watched content on Netflix is **Movies** compared to TV Shows.

# %%
df['release_year'].unique()

# %%
df.release_year.value_counts()
most_add = df.release_year.value_counts().sort_index(ascending=False)

# %%
most_add

# %%
'''import matplotlib.pyplot as plt

release_counts = df['release_year'].value_counts().sort_index()  # sort by year
release_counts.plot(kind='bar', color='g')
plt.xlabel('Release Year')
plt.ylabel('Number of Shows')
plt.title('Number of Shows Released per Year')
plt.show()
'''

# %% [markdown]
# ## observation
# Mosted movies add in 2018

# %%
df['listed_in'].unique()

# %%
all_genres = df['listed_in'].str.split(', ').explode()  # Split by comma and make each genre a row
popular_genres = all_genres.value_counts()  # Count frequency of each genre

# %%
all_genres

# %%
popular_genres

# %%
popular_genres.idxmax() , popular_genres.max() # for max value in this

# %% [markdown]
# ## obesrvation
# most popular International Movies in Netflix
